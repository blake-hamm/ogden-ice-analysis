# %%
import polars as pl

from ogden_ice_analysis import load_dataset

detentions = load_dataset("detention-stays-latest", lazy=False)
detentions.head()
# Out:
# shape: (5, 64)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ stay_ID   ┆ n_stints ┆ detention ┆ unique_id ┆ … ┆ detention ┆ detention ┆ book_in_d ┆ book_out_ │
# │ ---       ┆ ---      ┆ _facility ┆ entifier  ┆   ┆ _facility ┆ _facility ┆ ate_time_ ┆ date_time │
# │ str       ┆ i32      ┆ _codes_al ┆ ---       ┆   ┆ _last     ┆ _code_las ┆ last      ┆ _last     │
# │           ┆          ┆ l         ┆ str       ┆   ┆ ---       ┆ t         ┆ ---       ┆ ---       │
# │           ┆          ┆ ---       ┆           ┆   ┆ str       ┆ ---       ┆ datetime[ ┆ datetime[ │
# │           ┆          ┆ str       ┆           ┆   ┆           ┆ str       ┆ μs, UTC]  ┆ μs, UTC]  │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0000004d7 ┆ 3        ┆ AUSHOLD;  ┆ 0000004d7 ┆ … ┆ AZ REM OP ┆ IWAHOLD   ┆ 2025-11-2 ┆ 2025-11-2 │
# ...

# %%
facilities = load_dataset("facilities-latest", lazy=False)
facilities.head()
# Out:
# shape: (5, 24)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ detention ┆ name      ┆ address   ┆ city      ┆ … ┆ average_d ┆ average_m ┆ max_daily ┆ max_midn │
# │ _facility ┆ ---       ┆ ---       ┆ ---       ┆   ┆ aily_popu ┆ idnight_p ┆ _populati ┆ ight_pop │
# │ _code     ┆ str       ┆ str       ┆ str       ┆   ┆ lation_la ┆ opulation ┆ on_last_y ┆ ulation_ │
# │ ---       ┆           ┆           ┆           ┆   ┆ st_…      ┆ _la…      ┆ ear       ┆ last_y…  │
# │ str       ┆           ┆           ┆           ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ i32       ┆ i32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ IWAHOLD   ┆ AZ        ┆ 6335      ┆ Mesa      ┆ … ┆ 101.66575 ┆ 60.063014 ┆ 777       ┆ 499      │
# ...

# %%
ogden_facility = facilities.filter(pl.col("zip").str.contains("84401"))
display(ogden_facility)
ogden_facility_code = ogden_facility["detention_facility_code"]
# Out:
# shape: (1, 24)
# ┌────────────┬────────────┬────────────┬───────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ detention_ ┆ name       ┆ address    ┆ city  ┆ … ┆ average_d ┆ average_m ┆ max_daily ┆ max_midni │
# │ facility_c ┆ ---        ┆ ---        ┆ ---   ┆   ┆ aily_popu ┆ idnight_p ┆ _populati ┆ ght_popul │
# │ ode        ┆ str        ┆ str        ┆ str   ┆   ┆ lation_la ┆ opulation ┆ on_last_y ┆ ation_las │
# │ ---        ┆            ┆            ┆       ┆   ┆ st_…      ┆ _la…      ┆ ear       ┆ t_y…      │
# │ str        ┆            ┆            ┆       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆            ┆       ┆   ┆ f64       ┆ f64       ┆ i32       ┆ i32       │
# ╞════════════╪════════════╪════════════╪═══════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ OGUHOLD    ┆ Ogden Hold ┆ 2487 S.    ┆ Ogden ┆ … ┆ 1.506849  ┆ 0.043836  ┆ 13        ┆ 5         │
# ...

# %%
ogden_detentions = detentions.filter(
    pl.col("detention_facility_codes_all").str.contains(ogden_facility_code)
)
display(ogden_detentions)
# Out:
# shape: (947, 64)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ stay_ID   ┆ n_stints ┆ detention ┆ unique_id ┆ … ┆ detention ┆ detention ┆ book_in_d ┆ book_out_ │
# │ ---       ┆ ---      ┆ _facility ┆ entifier  ┆   ┆ _facility ┆ _facility ┆ ate_time_ ┆ date_time │
# │ str       ┆ i32      ┆ _codes_al ┆ ---       ┆   ┆ _last     ┆ _code_las ┆ last      ┆ _last     │
# │           ┆          ┆ l         ┆ str       ┆   ┆ ---       ┆ t         ┆ ---       ┆ ---       │
# │           ┆          ┆ ---       ┆           ┆   ┆ str       ┆ ---       ┆ datetime[ ┆ datetime[ │
# │           ┆          ┆ str       ┆           ┆   ┆           ┆ str       ┆ μs, UTC]  ┆ μs, UTC]  │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 002e3859d ┆ 4        ┆ OGUHOLD;  ┆ 002e3859d ┆ … ┆ NEVADA    ┆ NVSDCNV   ┆ 2023-06-0 ┆ 2023-06-1 │
# ...
