# %%
from ogden_ice_analysis import load_dataset

df_arrests = load_dataset("arrests-latest", lazy=False)
df_arrests.head()
# Out:
# shape: (5, 28)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ apprehens ┆ apprehens ┆ apprehens ┆ apprehens ┆ … ┆ duplicate ┆ file_orig ┆ sheet_ori ┆ row_orig │
# │ ion_date  ┆ ion_type  ┆ ion_state ┆ ion_aor   ┆   ┆ _likely   ┆ inal      ┆ ginal     ┆ inal     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ date      ┆ str       ┆ str       ┆ str       ┆   ┆ bool      ┆ str       ┆ str       ┆ i32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2022-10-0 ┆ null      ┆ TEXAS     ┆ San       ┆ … ┆ false     ┆ 2026-ICLI ┆ FY2023    ┆ 124239   │
# │ 1         ┆           ┆           ┆ Antonio   ┆   ┆           ┆ -00005_Ar ┆           ┆          │
# │           ┆           ┆           ┆ Area of   ┆   ┆           ┆ rests_FY2 ┆           ┆          │
# ...
